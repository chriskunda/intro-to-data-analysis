# %%
import pandas as pd
# Out:
# Failed to start the Kernel 'Python 3 (ipykernel)'.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details. Unable to get resolved server information for google.colab:colab:63c607a8-8435-4b14-9ad9-c653cbbfdff3

# %%
import pandas as pd

print("Jupyter is working!")
# Out:
# Jupyter is working!

# %%
sales = pd.read_csv("sales_data.csv", parse_dates=["Dates"])
