# %%
# %pip install google-cloud-bigquery
# Out:
# Collecting google-cloud-bigquery
#   Using cached google_cloud_bigquery-3.44.0-py3-none-any.whl.metadata (8.4 kB)
# Collecting google-api-core<3.0.0,>=2.28.0 (from google-api-core[grpc]<3.0.0,>=2.28.0->google-cloud-bigquery)
#   Using cached google_api_core-2.34.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting google-auth<3.0.0,>=2.14.1 (from google-auth[pyopenssl]<3.0.0,>=2.14.1->google-cloud-bigquery)
#   Using cached google_auth-2.57.0-py3-none-any.whl.metadata (6.0 kB)
# Collecting google-cloud-core<3.0.0,>=2.4.1 (from google-cloud-bigquery)
#   Using cached google_cloud_core-2.7.0-py3-none-any.whl.metadata (2.8 kB)
# Collecting google-resumable-media<3.0.0,>=2.0.0 (from google-cloud-bigquery)
#   Using cached google_resumable_media-2.10.2-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: packaging>=24.2.0 in c:\users\chris\anaconda3\lib\site-packages (from google-cloud-bigquery) (25.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.2 in c:\users\chris\anaconda3\lib\site-packages (from google-cloud-bigquery) (2.9.0.post0)
# Requirement already satisfied: requests<3.0.0,>=2.21.0 in c:\users\chris\anaconda3\lib\site-packages (from google-cloud-bigquery) (2.32.5)
# Collecting googleapis-common-protos<2.0.0,>=1.69.2 (from google-api-core<3.0.0,>=2.28.0->google-api-core[grpc]<3.0.0,>=2.28.0->google-cloud-bigquery)
#   Using cached googleapis_common_protos-1.75.2-py3-none-any.whl.metadata (8.5 kB)
# Collecting protobuf<8.0.0,>=6.33.5 (from google-api-core<3.0.0,>=2.28.0->google-api-core[grpc]<3.0.0,>=2.28.0->google-cloud-bigquery)
#   Using cached protobuf-7.36.0-cp310-abi3-win_amd64.whl.metadata (595 bytes)
# Collecting proto-plus<2.0.0,>=1.26.1 (from google-api-core<3.0.0,>=2.28.0->google-api-core[grpc]<3.0.0,>=2.28.0->google-cloud-bigquery)
#   Using cached proto_plus-1.28.4-py3-none-any.whl.metadata (2.2 kB)
# Collecting requests<3.0.0,>=2.21.0 (from google-cloud-bigquery)
#   Using cached requests-2.34.2-py3-none-any.whl.metadata (4.8 kB)
# Collecting grpcio<2.0.0,>=1.59.0 (from google-api-core[grpc]<3.0.0,>=2.28.0->google-cloud-bigquery)
#   Downloading grpcio-1.83.1-cp313-cp313-win_amd64.whl.metadata (3.8 kB)
# Collecting grpcio-status<2.0.0,>=1.59.0 (from google-api-core[grpc]<3.0.0,>=2.28.0->google-cloud-bigquery)
#   Using cached grpcio_status-1.83.1-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\chris\anaconda3\lib\site-packages (from google-auth<3.0.0,>=2.14.1->google-auth[pyopenssl]<3.0.0,>=2.14.1->google-cloud-bigquery) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in c:\users\chris\anaconda3\lib\site-packages (from google-auth<3.0.0,>=2.14.1->google-auth[pyopenssl]<3.0.0,>=2.14.1->google-cloud-bigquery) (46.0.3)
# Collecting google-crc32c<2.0.0,>=1.0.0 (from google-resumable-media<3.0.0,>=2.0.0->google-cloud-bigquery)
#   Downloading google_crc32c-1.8.0-cp313-cp313-win_amd64.whl.metadata (1.8 kB)
# Requirement already satisfied: typing-extensions~=4.12 in c:\users\chris\anaconda3\lib\site-packages (from grpcio<2.0.0,>=1.59.0->google-api-core[grpc]<3.0.0,>=2.28.0->google-cloud-bigquery) (4.15.0)
# Requirement already satisfied: six>=1.5 in c:\users\chris\anaconda3\lib\site-packages (from python-dateutil<3.0.0,>=2.8.2->google-cloud-bigquery) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\chris\anaconda3\lib\site-packages (from requests<3.0.0,>=2.21.0->google-cloud-bigquery) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\chris\anaconda3\lib\site-packages (from requests<3.0.0,>=2.21.0->google-cloud-bigquery) (3.11)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\chris\anaconda3\lib\site-packages (from requests<3.0.0,>=2.21.0->google-cloud-bigquery) (2.5.0)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\chris\anaconda3\lib\site-packages (from requests<3.0.0,>=2.21.0->google-cloud-bigquery) (2026.6.17)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\chris\anaconda3\lib\site-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.14.1->google-auth[pyopenssl]<3.0.0,>=2.14.1->google-cloud-bigquery) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\chris\anaconda3\lib\site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.14.1->google-auth[pyopenssl]<3.0.0,>=2.14.1->google-cloud-bigquery) (2.23)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in c:\users\chris\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.14.1->google-auth[pyopenssl]<3.0.0,>=2.14.1->google-cloud-bigquery) (0.6.1)
# Using cached google_cloud_bigquery-3.44.0-py3-none-any.whl (267 kB)
# Using cached google_api_core-2.34.0-py3-none-any.whl (180 kB)
# Using cached google_auth-2.57.0-py3-none-any.whl (259 kB)
# Using cached google_cloud_core-2.7.0-py3-none-any.whl (31 kB)
# Using cached google_resumable_media-2.10.2-py3-none-any.whl (81 kB)
# Downloading google_crc32c-1.8.0-cp313-cp313-win_amd64.whl (34 kB)
# Using cached googleapis_common_protos-1.75.2-py3-none-any.whl (307 kB)
# Downloading grpcio-1.83.1-cp313-cp313-win_amd64.whl (5.2 MB)
#    ---------------------------------------- 0.0/5.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.2 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/5.2 MB ? eta -:--:--
#    ------ --------------------------------- 0.8/5.2 MB 2.0 MB/s eta 0:00:03
#    ---------------- ----------------------- 2.1/5.2 MB 3.1 MB/s eta 0:00:01
#    -------------------------- ------------- 3.4/5.2 MB 3.8 MB/s eta 0:00:01
#    ------------------------------------ --- 4.7/5.2 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------- 5.2/5.2 MB 3.7 MB/s  0:00:01
# Using cached grpcio_status-1.83.1-py3-none-any.whl (14 kB)
# Using cached proto_plus-1.28.4-py3-none-any.whl (50 kB)
# Using cached protobuf-7.36.0-cp310-abi3-win_amd64.whl (453 kB)
# Using cached requests-2.34.2-py3-none-any.whl (73 kB)
# Installing collected packages: requests, protobuf, grpcio, google-crc32c, proto-plus, googleapis-common-protos, google-resumable-media, grpcio-status, google-auth, google-api-core, google-cloud-core, google-cloud-bigquery
#
#   Attempting uninstall: requests
#
#     Found existing installation: requests 2.32.5
#
#     Uninstalling requests-2.32.5:
#
#       Successfully uninstalled requests-2.32.5
#
#    ----------------------------------------  0/12 [requests]
#    ----------------------------------------  0/12 [requests]
#    ----------------------------------------  0/12 [requests]
#   Attempting uninstall: protobuf
#    ----------------------------------------  0/12 [requests]
#     Found existing installation: protobuf 5.29.3
#    ----------------------------------------  0/12 [requests]
#    --- ------------------------------------  1/12 [protobuf]
#    --- ------------------------------------  1/12 [protobuf]
#     Uninstalling protobuf-5.29.3:
#    --- ------------------------------------  1/12 [protobuf]
#       Successfully uninstalled protobuf-5.29.3
#    --- ------------------------------------  1/12 [protobuf]
#    --- ------------------------------------  1/12 [protobuf]
#    --- ------------------------------------  1/12 [protobuf]
#    --- ------------------------------------  1/12 [protobuf]
#    --- ------------------------------------  1/12 [protobuf]
#    --- ------------------------------------  1/12 [protobuf]
#    --- ------------------------------------  1/12 [protobuf]
#    --- ------------------------------------  1/12 [protobuf]
#    --- ------------------------------------  1/12 [protobuf]
#    --- ------------------------------------  1/12 [protobuf]
#    ------ ---------------------------------  2/12 [grpcio]
#    ------ ---------------------------------  2/12 [grpcio]
#    ------ ---------------------------------  2/12 [grpcio]
#    ------ ---------------------------------  2/12 [grpcio]
#    ------ ---------------------------------  2/12 [grpcio]
#    ------ ---------------------------------  2/12 [grpcio]
#    ------ ---------------------------------  2/12 [grpcio]
#    ------ ---------------------------------  2/12 [grpcio]
#    ---------- -----------------------------  3/12 [google-crc32c]
#    ------------- --------------------------  4/12 [proto-plus]
#    ------------- --------------------------  4/12 [proto-plus]
#    ---------------- -----------------------  5/12 [googleapis-common-protos]
#    ---------------- -----------------------  5/12 [googleapis-common-protos]
#    ---------------- -----------------------  5/12 [googleapis-common-protos]
#    ---------------- -----------------------  5/12 [googleapis-common-protos]
#    ---------------- -----------------------  5/12 [googleapis-common-protos]
#    ---------------- -----------------------  5/12 [googleapis-common-protos]
#    ---------------- -----------------------  5/12 [googleapis-common-protos]
#    ---------------- -----------------------  5/12 [googleapis-common-protos]
#    ---------------- -----------------------  5/12 [googleapis-common-protos]
#    ---------------- -----------------------  5/12 [googleapis-common-protos]
#    ---------------- -----------------------  5/12 [googleapis-common-protos]
#    ---------------- -----------------------  5/12 [googleapis-common-protos]
#    -------------------- -------------------  6/12 [google-resumable-media]
#    -------------------- -------------------  6/12 [google-resumable-media]
#    -------------------- -------------------  6/12 [google-resumable-media]
#    ----------------------- ----------------  7/12 [grpcio-status]
#    -------------------------- -------------  8/12 [google-auth]
#    -------------------------- -------------  8/12 [google-auth]
#    -------------------------- -------------  8/12 [google-auth]
#    -------------------------- -------------  8/12 [google-auth]
#    -------------------------- -------------  8/12 [google-auth]
#    -------------------------- -------------  8/12 [google-auth]
#    -------------------------- -------------  8/12 [google-auth]
#    -------------------------- -------------  8/12 [google-auth]
#    -------------------------- -------------  8/12 [google-auth]
#    -------------------------- -------------  8/12 [google-auth]
#    -------------------------- -------------  8/12 [google-auth]
#    ------------------------------ ---------  9/12 [google-api-core]
#    ------------------------------ ---------  9/12 [google-api-core]
#    ------------------------------ ---------  9/12 [google-api-core]
#    ------------------------------ ---------  9/12 [google-api-core]
#    ------------------------------ ---------  9/12 [google-api-core]
#    ------------------------------ ---------  9/12 [google-api-core]
#    ------------------------------ ---------  9/12 [google-api-core]
#    ------------------------------ ---------  9/12 [google-api-core]
#    ------------------------------ ---------  9/12 [google-api-core]
#    --------------------------------- ------ 10/12 [google-cloud-core]
#    --------------------------------- ------ 10/12 [google-cloud-core]
#    ------------------------------------ --- 11/12 [google-cloud-bigquery]
#    ------------------------------------ --- 11/12 [google-cloud-bigquery]
#    ------------------------------------ --- 11/12 [google-cloud-bigquery]
#    ------------------------------------ --- 11/12 [google-cloud-bigquery]
#    ------------------------------------ --- 11/12 [google-cloud-bigquery]
#    ------------------------------------ --- 11/12 [google-cloud-bigquery]
#    ------------------------------------ --- 11/12 [google-cloud-bigquery]
#    ------------------------------------ --- 11/12 [google-cloud-bigquery]
#    ---------------------------------------- 12/12 [google-cloud-bigquery]
#
# Successfully installed google-api-core-2.34.0 google-auth-2.57.0 google-cloud-bigquery-3.44.0 google-cloud-core-2.7.0 google-crc32c-1.8.0 google-resumable-media-2.10.2 googleapis-common-protos-1.75.2 grpcio-1.83.1 grpcio-status-1.83.1 proto-plus-1.28.4 protobuf-7.36.0 requests-2.34.2
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# streamlit 1.51.0 requires protobuf<7,>=3.20, but you have protobuf 7.36.0 which is incompatible.

# %%
from google.cloud import bigquery

# %%
client = bigquery.Client()
# Out:
# ---------------------------------------------------------------------------
# DefaultCredentialsError                   Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 client = bigquery.Client()
#
# File c:\Users\Chris\anaconda3\Lib\site-packages\google\cloud\bigquery\client.py:271, in Client.__init__(self, project, credentials, _http, location, default_query_job_config, default_load_job_config, client_info, client_options, default_job_creation_mode)
#     268     client_options = google.api_core.client_options.from_dict(client_options)
#     269 # assert isinstance(client_options, google.api_core.client_options.ClientOptions)
# --> 271 super(Client, self).__init__(
#     272     project=project,
#     273     credentials=credentials,
#     274     client_options=client_options,
#     275     _http=_http,
#     276 )
#     278 kw_args: Dict[str, Any] = {"client_info": client_info}
#     279 bq_host = _get_bigquery_host()
#
# File c:\Users\Chris\anaconda3\Lib\site-packages\google\cloud\client\__init__.py:360, in ClientWithProject.__init__(self, project, credentials, client_options, _http)
#     359 def __init__(self, project=None, credentials=None, client_options=None, _http=None):
# --> 360     _ClientProjectMixin.__init__(self, project=project, credentials=credentials)
#     361     Client.__init__(
#     362         self, credentials=credentials, client_options=client_options, _http=_http
#     363     )
#
# File c:\Users\Chris\anaconda3\Lib\site-packages\google\cloud\client\__init__.py:308, in _ClientProjectMixin.__init__(self, project, credentials)
#     305     project = getattr(credentials, "project_id", None)
#     307 if project is None:
# --> 308     project = self._determine_default(project)
#     310 if project is None:
#     311     raise EnvironmentError(
#     312         "Project was not passed and could not be "
#     313         "determined from the environment."
#     314     )
#
# File c:\Users\Chris\anaconda3\Lib\site-packages\google\cloud\client\__init__.py:327, in _ClientProjectMixin._determine_default(project)
#     324 @staticmethod
#     325 def _determine_default(project):
#     326     """Helper:  use default project detection."""
# --> 327     return _determine_default_project(project)
#
# File c:\Users\Chris\anaconda3\Lib\site-packages\google\cloud\_helpers\__init__.py:170, in _determine_default_project(project)
#     158 """Determine default project ID explicitly or implicitly as fall-back.
#     159
#     160 See :func:`google.auth.default` for details on how the default project
#    (...)    167 :returns: Default project if it can be determined.
#     168 """
#     169 if project is None:
# --> 170     _, project = google.auth.default()
#     171 return project
#
# File c:\Users\Chris\anaconda3\Lib\site-packages\google\auth\_default.py:748, in default(scopes, request, quota_project_id, default_scopes)
#     740             _LOGGER.warning(
#     741                 "No project ID could be determined. Consider running "
#     742                 "`gcloud config set project` or setting the %s "
#     743                 "environment variable",
#     744                 environment_vars.PROJECT,
#     745             )
#     746         return credentials, effective_project_id
# --> 748 raise exceptions.DefaultCredentialsError(_CLOUD_SDK_MISSING_CREDENTIALS)
#
# DefaultCredentialsError: Your default credentials were not found. To set up Application Default Credentials, see https://cloud.google.com/docs/authentication/external/set-up-adc for more information.

# %%
# Set up feedack system
from learntools.core import binder
binder.bind(globals())
from learntools.sql.ex1 import *
print("Setup Complete")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 2
#       1 # Set up feedack system
# ----> 2 from learntools.core import binder
#       3 binder.bind(globals())
#       4 from learntools.sql.ex1 import *
#
# ModuleNotFoundError: No module named 'learntools'
